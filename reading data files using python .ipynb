# %% [markdown]
# READING TEXT FILES

# %%
import pandas as pd
df = pd.read_table("text file.txt",sep=",")
df
# Out:
#    PersonID   LastName FirstName  Age
# 0         1     Hansen       Ola   30
# 1         2   Svendson      Tove   23
# 2         3  Pettersen      Kari   20

# %% [raw]
# READING EXCEL FILES

# %%
df2=pd.read_excel("shopping.xlsx")
df2
# Out:
#     ITEM ID        DATE               ITEM      CATEGORY      STORE   \
# 0          1 2023-03-09           Lentiles       legumes  No frills
# 1          2        NaT              Beans       legumes  No frills
# 2          3        NaT           ChicPeas       legumes  No frills
# 3          4        NaT            Chicken          meat  No frills
# 4          5        NaT               Pork          meat  No frills
# 5          6        NaT           Spinarch   vegetables   No frills
# 6          7        NaT           Broccoli   vegetables   No frills
# 7          8        NaT      Peanut butter        Spread  No frills
# 8          9        NaT   Unsalted butter         frying  No frills
# 9         10        NaT              Bread  whole wheat   No frills
# 10        11        NaT       Avocado oil         frying  No frills
# 11        12        NaT                tea      Caffeine  No frills
# 12        13        NaT         matcha tea      Caffeine         T&T
# ...

# %% [raw]
# READING JSON FILES

# %%
df3 = pd.read_json("jay.json")
df3
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# READING CSV FILES

# %%
df4=pd.read_csv("cities.csv")
df4
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...
