# %%
import pandas as pd 
import numpy as np 
import plotly.express as px
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# I download the top canadian companies ticker symbols info using the download method/function
multi_tickers=yf.download("RY,CP,TD",start="2018-01-01",end="2023-04-27",group_by="tickers")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
# we can view the information in history like format below
multi_tickers
# Out:
#                    RY                                                         \
#                  Open        High        Low       Close  Adj Close   Volume
# Date
# 2018-01-02  81.809998   82.330002  81.580002   82.330002  67.036926   555200
# 2018-01-03  82.269997   83.110001  82.269997   82.839996  67.452187   713500
# 2018-01-04  83.190002   84.120003  82.940002   83.919998  68.331573  1016600
# 2018-01-05  84.500000   84.699997  84.309998   84.400002  68.722420   467300
# 2018-01-08  84.349998   84.529999  83.959999   84.029999  68.421135   530900
# ...               ...         ...        ...         ...        ...      ...
# 2023-04-20  99.510002  100.330002  99.400002  100.000000  99.024414  4761400
# 2023-04-21  99.599998  100.019997  98.980003   99.940002  98.965004  1364000
# 2023-04-24  99.029999   99.050003  98.199997   98.669998  98.669998  2675100
# 2023-04-25  98.059998   98.400002  96.199997   96.639999  96.639999   695400
# ...

# %%
#Below I plot all the companies information 

multi_tickers.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#I break down  to specifically TD information
multi_tickers["TD"]
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2018-01-02  58.820000  59.150002  58.520000  58.910000  47.085278  1424500
# 2018-01-03  58.880001  59.360001  58.880001  59.169998  47.293087   854000
# 2018-01-04  59.430000  59.889999  59.270000  59.830002  47.820610  1233800
# 2018-01-05  60.360001  60.509998  60.139999  60.349998  48.236240  1015700
# 2018-01-08  60.270000  60.540001  60.160000  60.200001  48.116341  1047100
# ...               ...        ...        ...        ...        ...      ...
# 2023-04-20  61.630001  62.070000  61.599998  61.959999  61.959999  1406600
# 2023-04-21  61.669998  61.790001  60.950001  61.709999  61.709999  1616900
# 2023-04-24  61.549999  61.740002  60.830002  61.119999  61.119999  1539100
# 2023-04-25  60.450001  60.660000  59.470001  59.509998  59.509998  2122500
# 2023-04-26  59.450001  59.959999  59.160000  59.509998  59.509998  1915500
#
# [1338 rows x 6 columns]

# %%
multi_tickers["TD"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig=px.line(multi_tickers["TD"]
           )
fig.show()
# Out:
# <div>                            <div id="60e76bfd-6f3e-42ca-ab6c-41470578740e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60e76bfd-6f3e-42ca-ab6c-41470578740e")) {                    Plotly.newPlot(                        "60e76bfd-6f3e-42ca-ab6c-41470578740e",                        [{"hovertemplate":"variable=Open<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Open","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Open","showlegend":true,"x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-
# ...

# %%
multi_tickers["TD"]["Open"]
# Out:
# Date
# 2018-01-02    58.820000
# 2018-01-03    58.880001
# 2018-01-04    59.430000
# 2018-01-05    60.360001
# 2018-01-08    60.270000
#                 ...
# 2023-04-20    61.630001
# 2023-04-21    61.669998
# 2023-04-24    61.549999
# 2023-04-25    60.450001
# 2023-04-26    59.450001
# Name: Open, Length: 1338, dtype: float64

# %%
# Here we look at the opening date of CP and RY
multi_tickers.loc[:,("CP"):("RY")]
# Out:
#                    CP                                                       \
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2018-01-02  36.639999  36.840000  36.372002  36.650002  34.906525  2185500
# 2018-01-03  36.703999  36.834000  36.506001  36.736000  34.988434  1734500
# 2018-01-04  36.838001  37.051998  36.708000  36.793999  35.043674  1592000
# 2018-01-05  37.020000  37.234001  36.820000  36.952000  35.194160  2851500
# 2018-01-08  36.953999  37.344002  36.868000  37.276001  35.502743  1655000
# ...               ...        ...        ...        ...        ...      ...
# 2023-04-20  80.230003  81.239998  79.769997  80.760002  80.760002  1243100
# 2023-04-21  81.269997  82.040001  80.790001  81.290001  81.290001  1844500
# 2023-04-24  81.269997  82.019997  81.029999  81.300003  81.300003  1215500
# 2023-04-25  80.910004  81.089996  77.930000  79.269997  79.269997  2026700
# ...

# %%
multi_tickers.loc[:,"CP":"RY"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#I use plotly.express to graph CP's earnings 
fig=px.scatter(multi_tickers["CP"]["Open"], color = multi_tickers["CP"]["Open"] )
fig.show()
# Out:
# <div>                            <div id="da9c0935-9fb9-4270-be2d-927fc3254143" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da9c0935-9fb9-4270-be2d-927fc3254143")) {                    Plotly.newPlot(                        "da9c0935-9fb9-4270-be2d-927fc3254143",                        [{"hovertemplate":"Date=%{x}<br>value=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[36.63999938964844,36.70399856567383,36.8380012512207,37.02000045776367,36.95399856567383,37.400001525878906,37.20000076293945,36.03200149536133,36.8120002746582,36.874000549316406,36.439998626708984,36.36600112915039,36.58599853515625,37.242000579833984,37.21200180053711,37.08000183105469,37.47600173950195,37.41600036621094,37.279998779296875,37.
# ...
